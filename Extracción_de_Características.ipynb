# %% [markdown]
# <a href="https://colab.research.google.com/github/A01737866/Extraccion-de-Caracteristicas/blob/main/Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerías pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin índice
Micro_Retailer = pd.read_excel("microretailer_mit_lift_lab.xlsx")

# %%
Micro_Retailer.head()

# %%
Filtro = Micro_Retailer.iloc[:, [3,9,15,18,23,24,26,27,35,36,47,55,67,68,71,72,74,75,83,88]]
Filtro

# %%
#identificar valores nulos por columna
valores_nulos = Filtro.isnull().sum()
valores_nulos
# Out:
# _updated_by                                                     0
# 232_type_of_store                                               0
# 184_store_devices                                               2
# hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz      0
# 5_change_store_space_last_year                                 72
# 6_change_employees_average_salary_last_year                    86
# 49_inventory_records                                           61
# 18_sales_records                                               61
# 210_sales_channels                                             89
# 189_payment_methods                                            64
# 214_customer_relationship_tools                                76
# 60_services                                                    94
# 312_payment_of_utilities                                      105
# 313_home_deliveries                                           113
# ...

# %%
#Realizamos una copia del dataframe
Filtro1 = Filtro.copy()

# %%
#Sustituir valores nulos por un string en concreto
Filtro1["184_store_devices"] = Filtro1["184_store_devices"].fillna("Smartphone")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["5_change_store_space_last_year"] = Filtro1["5_change_store_space_last_year"].fillna("No cambió")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["6_change_employees_average_salary_last_year"] = Filtro1["6_change_employees_average_salary_last_year"].fillna("No cambió")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["49_inventory_records"] = Filtro1["49_inventory_records"].fillna("No se recabó información")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["18_sales_records"] = Filtro1["18_sales_records"].fillna("No se recabó información")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["210_sales_channels"] = Filtro1["210_sales_channels"].fillna("Llamada a Teléfono celular")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["189_payment_methods"] = Filtro1["189_payment_methods"].fillna("Efectivo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["214_customer_relationship_tools"] = Filtro1["214_customer_relationship_tools"].fillna("No se recabó información")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["60_services"] = Filtro1["60_services"].fillna("Ninguno")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["312_payment_of_utilities"] = Filtro1["312_payment_of_utilities"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["313_home_deliveries"] = Filtro1["313_home_deliveries"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["44_willingness_inventory_management_suppliers"] = Filtro1["44_willingness_inventory_management_suppliers"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["45_willingness_reorder_suppliers"] = Filtro1["45_willingness_reorder_suppliers"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["47_willingness_reorder_suppliers_lower_prices"] = Filtro1["47_willingness_reorder_suppliers_lower_prices"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["43_willingness_share_sales_data_suppliers"] = Filtro1["43_willingness_share_sales_data_suppliers"].fillna("Ni de acuerdo ni en desacuerdo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["277_payment_method_suppliers"] = Filtro1["277_payment_method_suppliers"].fillna("Efectivo")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
Filtro1["161_actions_stockouts"] = Filtro1["161_actions_stockouts"].fillna("No se recabó información")

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos

# %%
#Verificamos información del Dataframe
Filtro1.info()

# %% [markdown]
# **Se observa que se cuenta con puras variables categóricas por lo cual no hay Outliers**

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Filtro1)

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["_updated_by"])
table1

# %%
 #Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>=1] #>3
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("_updated_by")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Personas que recolectaron datos")
plt.xlabel("Nombre del alumno")
plt.ylabel("Frecuencia")

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["232_type_of_store"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro3 = table1[table1["frequency"]>1]
Filtro3

# %%
#Ajusto el índice de mi dataframe
Filtro_index1 = Filtro3.set_index("232_type_of_store")
Filtro_index1

# %%
Filtro4 = Filtro_index1.iloc[:, [0,1]]
Filtro4

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro4.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Tipos de tiendas")
plt.xlabel("Tipo de tienda")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos gráfico de área del dataframe filtrado
Filtro4.plot(kind = "area", figsize = (20,4), alpha = 0.5)
# Out:
# <Axes: xlabel='232_type_of_store'>

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["184_store_devices"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>4]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("184_store_devices")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
Filtro_index["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Store Devices")

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>57]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("¿Se realizó la encuesta?")
# Out:
# Text(0.5, 1.0, '¿Se realizó la encuesta?')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["5_change_store_space_last_year"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>0]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("5_change_store_space_last_year")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("¿Cambió el espacio de la tienda el último año?")
plt.xlabel("Porcentaje")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["6_change_employees_average_salary_last_year"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["cumulative_perc"]<0.982457]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("6_change_employees_average_salary_last_year")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("¿Cambió el salario de los empleados de la tienda el último año?")
plt.xlabel("Porcentaje")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["49_inventory_records"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>7]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("49_inventory_records")
Filtro_index

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Control de inventario")
# Out:
# Text(0.5, 1.0, 'Control de inventario')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["18_sales_records"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>3]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("18_sales_records")
Filtro_index

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Control de ventas")
# Out:
# Text(0.5, 1.0, 'Control de ventas')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["210_sales_channels"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("210_sales_channels")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Canales de ventas")
plt.xlabel("Tipo de canal")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["189_payment_methods"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("189_payment_methods")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro2["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Métodos de pago")
# Out:
# Text(0.5, 1.0, 'Métodos de pago')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["214_customer_relationship_tools"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("214_customer_relationship_tools")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0]]
Filtro2

# %%
#Realizamos gráfico de área del dataframe filtrado
Filtro2.plot(kind = "area", figsize = (15,4), alpha = 0.5)
plt.title("Bitácora de clientes")
# Out:
# Text(0.5, 1.0, 'Bitácora de clientes')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["60_services"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("60_services")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Servicios")
plt.xlabel("Tipo de Servicio")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["312_payment_of_utilities"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("312_payment_of_utilities")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro2["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Pago de utilidades")
# Out:
# Text(0.5, 1.0, 'Pago de utilidades')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["313_home_deliveries"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>4]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("313_home_deliveries")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0]]
Filtro2

# %%
#Realizamos gráfico de área del dataframe filtrado
Filtro2.plot(kind = "area", figsize = (15,4), alpha = 0.5)
plt.title("Entrega a domicilio")
# Out:
# Text(0.5, 1.0, 'Entrega a domicilio')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["44_willingness_inventory_management_suppliers"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>2]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("44_willingness_inventory_management_suppliers")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamos gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Disposición de proveedores en gestión de inventario")
plt.xlabel("Opinión")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["45_willingness_reorder_suppliers"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>8]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("45_willingness_reorder_suppliers")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0]]
Filtro2
# Out:
#                                   frequency
# 45_willingness_reorder_suppliers
# Ni de acuerdo ni en desacuerdo          100
# Totalmente en desacuerdo                 40
# Algo de acuerdo                          12
# Algo en desacuerdo                       10
# Totalmente de acuerdo                     9

# %%
#Realizamos gráfico de área del dataframe filtrado
Filtro2.plot(kind = "area", figsize = (15,4), alpha = 0.5)
plt.title("Voluntad de reordenar suministros")
# Out:
# Text(0.5, 1.0, 'Voluntad de reordenar suministros')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["47_willingness_reorder_suppliers_lower_prices"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>4]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("47_willingness_reorder_suppliers_lower_prices")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0]]
Filtro2

# %%
#Realizamos gráfico de pastel del dataframe filtrado
Filtro2["frequency"].plot(kind="pie", figsize=(10, 5), shadow=True, autopct="%1.1f%%")
plt.title("Reordenar proveedores a precios más bajos")
# Out:
# Text(0.5, 1.0, 'Reordenar proveedores a precios más bajos')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["43_willingness_share_sales_data_suppliers"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>2]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("43_willingness_share_sales_data_suppliers")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0]]
Filtro2

# %%
#Realizamos gráfico de área del dataframe filtrado
Filtro2.plot(kind = "area", figsize = (15,4), alpha = 0.5)
plt.title("Voluntad de compartir datos de ventas con proveedores")
# Out:
# Text(0.5, 1.0, 'Voluntad de compartir datos de ventas con proveedores')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["277_payment_method_suppliers"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>1]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("277_payment_method_suppliers")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("Formas de pago a proveedores")
plt.xlabel("Forma de pago")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis universitario de una variable categórica en específico
table1 = freq_tbl(Filtro1["161_actions_stockouts"])
table1

# %%
#Obtengo un filtro de los valores más relevantes de la variable categórica seleccionada
Filtro = table1[table1["frequency"]>4]
Filtro

# %%
#Ajusto el índice de mi dataframe
Filtro_index = Filtro.set_index("161_actions_stockouts")
Filtro_index

# %%
Filtro2 = Filtro_index.iloc[:, [0,1]]
Filtro2
# Out:
#                                                     frequency  percentage
# 161_actions_stockouts
# No se recabó información                                   79    0.461988
# Solicitar tiempo al cliente para conseguir el p...         31    0.181287
# Ofrecer un producto sustituto                              20    0.116959
# Ofrecer un producto sustituto,Solicitar tiempo ...         12    0.070175
# Perder la venta                                             8    0.046784
# Informar al proveedor,Solicitar tiempo al clien...          5    0.029240
# Informar al proveedor                                       5    0.029240

# %%
#Realizamod gráfico de barras del dataframe filtrado
Filtro2.plot(kind = "bar", width = 1, figsize = (10,4))
plt.title("¿Qué se hace si no hay un producto en existencia?")
plt.xlabel("Alternativa")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#identificar valores nulos por columna
valores_nulos = Filtro1.isnull().sum()
valores_nulos
# Out:
# _updated_by                                                   0
# 232_type_of_store                                             0
# 184_store_devices                                             0
# hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz    0
# 5_change_store_space_last_year                                0
# 6_change_employees_average_salary_last_year                   0
# 49_inventory_records                                          0
# 18_sales_records                                              0
# 210_sales_channels                                            0
# 189_payment_methods                                           0
# 214_customer_relationship_tools                               0
# 60_services                                                   0
# 312_payment_of_utilities                                      0
# 313_home_deliveries                                           0
# 44_willingness_inventory_management_suppliers                 0
# ...
